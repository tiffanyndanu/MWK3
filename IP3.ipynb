# %% [markdown]
# # **DATA PREPARATION.**

# %% [markdown]
# ## **Importing Libraries**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# The telecom data provided for this project will be as follows:
#
# 1.cells_geo_description.xlsx [Link] (Links to an external site.)
#
# 2.cells_geo.csv [Link] (Links to an external site.)
#
# 3.CDR_description.xlsx [Link] (Links to an external site.)
#
# 4.CDR 20120507 [http://bit.ly/TelecomDataset1] (Links to an external site.)
#
# 5.CDR 20120508 [http://bit.ly/TelecomDataset2] (Links to an external site.)
#
# 6.CDR 20120509 [http://bit.ly/TelecomDataset3]

# %% [markdown]
# # **LOADING DATASETS.**

# %%
df = pd.read_csv('/content/cells_geo.csv')
df
df[';VILLES;STATUS;LOCALISATION;DECOUPZONE;ZONENAME;LONGITUDE;LATITUDE;REGION;AREA;CELL_ID;SITE_CODE'].str.split(';', expand=True)
# Out:
#         0         1           2   ...            9           10          11
# 0        0    ADJAME  In Service  ...                fbb2e75af3  0bb492ef17
# 1        1    ADJAME  In Service  ...                1502501d78  0bb492ef17
# 2        2    ADJAME  In Service  ...                0c2e182a0c  0bb492ef17
# 3        3   ASSINIE  In Service  ...                69bdfc69fd  8a1e6ce31f
# 4        4   ASSINIE  In Service  ...                7a1029d2ab  8a1e6ce31f
# ...    ...       ...         ...  ...           ...         ...         ...
# 3969  3969  ZUENOULA  In Service  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  3970  ZUENOULA  In Service  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  3971  ZUENOULA  In Service  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  3972  ZUENOULA  In Service  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# 3973  3973  ZUENOULA  In Service  ...  CENTRE NORTH  f9f3e42589  61bee9c70c
#
# [3974 rows x 12 columns]

# %%
df= pd.read_csv('cells_geo.csv', sep= ';')
df
# Out:
#       Unnamed: 0    VILLES      STATUS  ...          AREA     CELL_ID   SITE_CODE
# 0              0    ADJAME  In Service  ...           NaN  fbb2e75af3  0bb492ef17
# 1              1    ADJAME  In Service  ...           NaN  1502501d78  0bb492ef17
# 2              2    ADJAME  In Service  ...           NaN  0c2e182a0c  0bb492ef17
# 3              3   ASSINIE  In Service  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4              4   ASSINIE  In Service  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...          ...       ...         ...  ...           ...         ...         ...
# 3969        3969  ZUENOULA  In Service  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970        3970  ZUENOULA  In Service  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971        3971  ZUENOULA  In Service  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972        3972  ZUENOULA  In Service  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
CGD_Data = pd.read_excel("/content/cells_geo_description.xlsx")
CGD_Data
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
CDR_Data = pd.read_excel("/content/CDR_description.xlsx")
CDR_Data
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
# Creating dataframe.

df_url = "http://bit.ly/TelecomDataset1"
df1 = pd.read_csv(df_url)
df1
# Out:
#          PRODUTC  VALUE  ...     CELL_ID     SITE_ID
# 0          Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1            sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2            sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice     14  ...  051KhYDCpv  051KhYDCpv
# ...          ...    ...  ...         ...         ...
# 15011811   Voice     40  ...  y8Zy+A5U3K  y8Zy+A5U3K
# 15011812     sms      0  ...  yGAZ0YDzFi  yGAZ0YDzFi
# 15011813     sms      0  ...  ywp1Gp+dk/  ywp1Gp+dk/
# 15011814     sms      0  ...  zsA2dnzCR5  zsA2dnzCR5
# 15011815     sms      0  ...  zn4qbCp2XH  zn4qbCp2XH
#
# [15011816 rows x 10 columns]

# %%
df_url = "http://bit.ly/TelecomDataset2"
df2 = pd.read_csv(df_url)
df2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d330b49fcef0> in <module>()
#       1 df_url = "http://bit.ly/TelecomDataset2"
# ----> 2 df2 = pd.read_csv(df_url)
#       3 df2
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# # **DATA CLEANING**

# %%
#dropping columns

# %% [markdown]
# ## **DATA ANALYSIS**

# %%
# Most used city for the 3 days
df7=df['LOCALISATION'].max()
df7
# Out:
# 'INTERIEUR'

# %%
#cities used the most during business and home hours
